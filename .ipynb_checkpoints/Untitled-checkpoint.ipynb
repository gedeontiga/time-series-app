# %% [markdown]
# <h1><b>AMBOMO TIGA GEDEON 21T2496</b></h1>

# %% [markdown]
# <h1>DEVOIR ANALYSE TEMPORELLE</h1>

# %% [markdown]
# <h2>1- <b><u> Étude production de bière<u></b></h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

filepath_1 = "dataset/monthly-beer-production-in-austr.csv"
df  = pd.read_csv(filepath_1);

# %% [markdown]
# <h2>2- <b><u>Moyenne, Variance et Ecart-type</u></b></h2>

# %%
mean_1 = df['Monthly beer production'].mean()
var_1 = df['Monthly beer production'].var()
ect_1 = df['Monthly beer production'].std()
print(f"moyenne: {mean_1}\nVarieance: {var_1}\nEcart-type: {ect_1}")
# Out:
# moyenne: 136.3953781512605
# Varieance: 1138.3015364882797
# Ecart-type: 33.738724583011134

# %% [markdown]
# <h2>3- <b><u>Représentation</u></b></h2>

# %%
plt.figure(figsize=(12,6))
df.plot(x='Month', y='Monthly beer production', c='b')
plt.xlabel("time")
plt.ylabel("value")
# plt.title("Temporal serie for prooduction")
plt.show()

# %% [markdown]
# <h2>4- <b><u>Nuage de points</u></b></h2>

# %%
plt.scatter(df['Month'], df['Monthly beer production'], s=10, c='b', label="Production serie")
plt.xlabel("time")
plt.ylabel("value")
# plt.title("Temporal serie for prooduction")
plt.show()

# %% [markdown]
# <h2>5- <b><u>Auto-correlations</u></b></h2>

# %%
autocorr = [df['Monthly beer production'].autocorr(lag=lag) for lag in range(1, 51)]
lags = range(1, 51)
plt.figure(figsize=(12, 6))
plt.plot(lags, autocorr, c='b', label="Production series")
plt.xlabel("time")
plt.ylabel("value")
# plt.title("Temporal serie for prooduction")
plt.show()

# %% [markdown]
# <h2>1- <b><u> Étude Bitcoin<u></b></h2>

# %%
filepath_2 = "dataset/BTC-EUR.csv"
df_2  = pd.read_csv(filepath_2);

# %% [markdown]
# <h2>2- <b><u> Moyenne, variance et Ecart-type<u></b></h2>

# %%
mean_2 = df_2['Close'].mean()
var_2 = df_2['Close'].var()
ect_2 = df_2['Close'].std()
print(f"moyenne: {mean_2}\nVarieance: {var_2}\nEcart-type: {ect_2}")
# Out:
# moyenne: 14163.800274366047
# Varieance: 244204415.66502538
# Ecart-type: 15627.04116795708

# %% [markdown]
# <h2>3- <b><u> Représentation <u></b></h2>

# %%
plt.figure(figsize=(12,6))
df_2.plot(x='Date', y='Close', c='b')
plt.xlabel("Date")
plt.ylabel("value")
# plt.title("Temporal serie for prooduction")
plt.show()

# %% [markdown]
# <h2>4- <b><u> Nuage de points <u></b></h2>

# %%
plt.scatter(df_2['Date'], df_2['Close'], s=1, c='b')
plt.xlabel("Date")
plt.ylabel("value")
# plt.title("Temporal serie for prooduction")
plt.show()

# %% [markdown]
# <h2>5- <b><u> Auto-correlation<u></b></h2>

# %%
autocorr = [df_2['Close'].autocorr(lag=lag) for lag in range(1, 51)]
lags = range(1, 51)
plt.figure(figsize=(12, 6))
plt.plot(lags, autocorr, c='b')
plt.xlabel("Date")
plt.ylabel("value")
# plt.title("Temporal serie for prooduction")
plt.show()

# %% [markdown]
# <h2>1- <b><u> Étude météo<u></b></h2>

# %%
filepath_3 = "dataset/weather_data_kolkata_2015_2020.csv"
df_3  = pd.read_csv(filepath_3);

# %% [markdown]
# <h2>2- <b><u> Moyenne, variance et Ecart-type<u></b></h2>

# %%
mean_3 = df_3['TEMPERATURE'].mean()
var_3 = df_3['TEMPERATURE'].var()
ect_3 = df_3['TEMPERATURE'].std()
print(f"moyenne: {mean_3}\nVarieance: {var_3}\nEcart-type: {ect_3}")
# Out:
# moyenne: 28.187633059610704
# Varieance: 24.466912655513195
# Ecart-type: 4.9464040125643995

# %% [markdown]
# <h2>3- <b><u> Représentation <u></b></h2>

# %%
plt.figure(figsize=(12,6))
df_3.plot(x='DATETIME', y='TEMPERATURE', c='b')
plt.xlabel("DATETIME")
plt.ylabel("value")
# plt.title("Temporal serie for prooduction")
plt.show()

# %% [markdown]
# <h2>4- <b><u> Nuage de points <u></b></h2>

# %%
# plt.scatter(df_3['DATETIME'], df_3['TEMPERATURE'], s=1, c='b')
# plt.xlabel("Date")
# plt.ylabel("value")
# # plt.title("Temporal serie for prooduction")
# plt.show()

# %% [markdown]
# <h2>5- <b><u> Auto-correlation<u></b></h2>

# %%
autocorr = [df_3['TEMPERATURE'].autocorr(lag=lag) for lag in range(1, 51)]
lags = range(1, 51)
plt.figure(figsize=(12, 6))
plt.plot(lags, autocorr, c='b')
plt.xlabel("datetime")
plt.ylabel("value")
# plt.title("Temporal serie for prooduction")
plt.show()

# %% [markdown]
# <h2>1- <b><u> Étude vente panneau solaire<u></b></h2>

# %%
filepath_4 = "dataset/monthly-sunspots.csv"
df_4  = pd.read_csv(filepath_4);

# %% [markdown]
# <h2>2- <b><u> Moyenne, variance et Ecart-type<u></b></h2>

# %%
mean_4 = df_4['Sunspots'].mean()
var_4 = df_4['Sunspots'].var()
ect_4 = df_4['Sunspots'].std()
print(f"moyenne: {mean_4}\nVarieance: {var_4}\nEcart-type: {ect_4}")
# Out:
# moyenne: 51.265957446808514
# Varieance: 1887.8131081642046
# Ecart-type: 43.44897131307258

# %% [markdown]
# <h2>3- <b><u> Représentation <u></b></h2>

# %%
plt.figure(figsize=(12,6))
df_4.plot(x='Date', y='Sunspots', c='b')
plt.xlabel("Date")
plt.ylabel("value")
# plt.title("Temporal serie for prooduction")
plt.show()

# %% [markdown]
# <h2>4- <b><u> Nuage de points <u></b></h2>

# %%
# plt.scatter(df_4['Date'], df_4['Sunspots'], s=1, c='b')
# plt.xlabel("Date")
# plt.ylabel("value")
# # plt.title("Temporal serie for prooduction")
# plt.show()

# %% [markdown]
# <h2>5- <b><u> Auto-correlation<u></b></h2>

# %%
autocorr = [df_4['Sunspots'].autocorr(lag=lag) for lag in range(1, 51)]
lags = range(1, 51)
plt.figure(figsize=(12, 6))
plt.plot(lags, autocorr, c='b')
plt.xlabel("Date")
plt.ylabel("value")
# plt.title("Temporal serie for prooduction")
plt.show()

# %% [markdown]
# <h2>1- <b><u> Étude production électrique<u></b></h2>

# %%
filepath_5 = "dataset/Electric_Production.csv"
df_5  = pd.read_csv(filepath_5);

# %% [markdown]
# <h2>2- <b><u> Moyenne, variance et Ecart-type<u></b></h2>

# %%
mean_5 = df_5['IPG2211A2N'].mean()
var_5 = df_5['IPG2211A2N'].var()
ect_5 = df_5['IPG2211A2N'].std()
print(f"moyenne: {mean_5}\nVarieance: {var_5}\nEcart-type: {ect_5}")
# Out:
# moyenne: 88.84721763224182
# Varieance: 236.78542489342567
# Ecart-type: 15.387833664730902

# %% [markdown]
# <h2>3- <b><u> Représentation <u></b></h2>

# %%
plt.figure(figsize=(12,6))
df_5.plot(x='DATE', y='IPG2211A2N', c='b')
plt.xlabel("Date")
plt.ylabel("value")
# plt.title("Temporal serie for prooduction")
plt.show()

# %% [markdown]
# <h2>4- <b><u> Nuage de points <u></b></h2>

# %%
plt.scatter(df_5['Date'], df_5['IPG2211A2N'], s=1, c='b')
plt.xlabel("Date")
plt.ylabel("value")
# plt.title("Temporal serie for prooduction")
plt.show()

# %% [markdown]
# <h2>5- <b><u> Auto-correlation<u></b></h2>

# %%
autocorr = [df_5['IPG2211A2N'].autocorr(lag=lag) for lag in range(1, 51)]
lags = range(1, 51)
plt.figure(figsize=(12, 6))
plt.plot(lags, autocorr, c='b')
plt.xlabel("Date")
plt.ylabel("value")
# plt.title("Temporal serie for prooduction")
plt.show()
